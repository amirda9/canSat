# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
img = cv2.imread('1.jpg' )
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(img)

# %%
bbox, label, conf = cv2.detect_common_objects(img)
output_image = draw_bbox(img, bbox, label, conf)
plt.imshow(output_image)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-df2f667f4d8e> in <module>
# ----> 1 bbox, label, conf = cv2.detect_common_objects(img)
#       2 output_image = draw_bbox(img, bbox, label, conf)
#       3 plt.imshow(output_image)
#       4 plt.show()
#
# AttributeError: module 'cv2' has no attribute 'detect_common_objects'

# %%
image, cnts, hierarchy = cv2.findContours(img, cv2.RETR_LIST, cv2.CHAIN_APPROX_SIMPLE)
external_contours = np.zeros(image.shape)
for i in range(len(cnts)):
    if hierarchy[0][i][3]== -1 :
        cv2.drawContours(external_contours,cnts,i,255,-1)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-20-a034e2f249ab> in <module>
# ----> 1 image, cnts, hierarchy = cv2.findContours(img, cv2.RETR_LIST, cv2.CHAIN_APPROX_SIMPLE)
#       2 external_contours = np.zeros(image.shape)
#       3 for i in range(len(cnts)):
#       4     if hierarchy[0][i][3]== -1 :
#       5         cv2.drawContours(external_contours,cnts,i,255,-1)
#
# error: OpenCV(3.4.2) C:\Miniconda3\conda-bld\opencv-suite_1534379934306\work\modules\imgproc\src\contours.cpp:199: error: (-210:Unsupported format or combination of formats) [Start]FindContours supports only CV_8UC1 images when mode != CV_RETR_FLOODFILL otherwise supports CV_32SC1 images only in function 'cvStartFindContours_Impl'

# %%
plt.imshow(external_contours)
